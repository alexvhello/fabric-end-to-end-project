# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

data = [(1, 'Lempiras'), (2, 'Dólares')]
schema = StructType([
    StructField("Id", IntegerType(), True),
    StructField("Descripcion", StringType(), True)
])

df = SparkSession.builder.getOrCreate().createDataFrame(data, schema)
df.write.mode("overwrite").saveAsTable("moneda")  # Esto la guarda en el Lakehouse
# Out:
# StatementMeta(, fea3fa5e-e5df-4df3-8a6c-db39ec34949c, 4, Finished, Available, Finished)
